# %% [markdown]
# <a href="https://colab.research.google.com/github/Kutmanegmkl/project1/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22dict_tuple_hw_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1
# Создайте словарь dict1 и удалите все его элементы специальным методом

# %%
dict1 ={"a":121,'b':312,'c':231}

# %%
dict1.clear()

# %%
dict1
# Out:
# {}

# %% [markdown]
# # Task 2
# Дан словарь dict_ = {'a': 1, 'b': 2, 'c': 1}, выведите все его ключи

# %%
dict_ = {'a': 1, 'b': 2, 'c': 1}

# %%
dict_.values()
# Out:
# dict_values([1, 2, 1])

# %% [markdown]
# # Task 3
# Используя предыдущий словарь проитерируйте его по парам ключ-значение
# и распечатайте каждую пару

# %%
for k,v in dict_.items():
  print(k,'--',v)
# Out:
# a -- 1
# b -- 2
# c -- 1

# %% [markdown]
# # Task 4
# Из словаря dict4 = {'a': 1, 'b': 4, 'c': 1, 'd': 5, 'e': 6}
# удалите пары у которых значение меньше 4

# %%
dict4 = {'a': 1, 'b': 4, 'c': 1, 'd': 5, 'e': 6}

# %%
for i in list(dict4):
  if dict4[i]<4:
    del dict4[i]
dict4
# Out:
# {'b': 4, 'd': 5, 'e': 6}

# %%
list(dict4)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# # Task 5
# Дан словарь
# ```
# dict5 = {1: {'a': 1}, 2: {'b': 4}, 3: {'c': 1}, 4: {'d': 5}, 5: {'e': 6}}
# ```
# Сделайте так, чтобы значениями внешних ключей были ключи внутренних словарей.
#
# Например {1: 'a', 2: 'b', ....}

# %%
dict5 = {1: {'a': 1}, 2: {'b': 4}, 3: {'c': 1}, 4: {'d': 5}, 5: {'e': 6}}

# %%
dict5 = {1: {'a': 1}, 2: {'b': 4}, 3: {'c': 1}, 4: {'d': 5}, 5: {'e': 6}}
for i in dict5:
  dict5[i]=list(dict5[i].keys())
dict5
# Out:
# {1: ['a'], 2: ['b'], 3: ['c'], 4: ['d'], 5: ['e']}

# %%
dict5[1]=list(dict5[1].keys())
dict5
# Out:
# {1: ['a'], 2: {'b': 4}, 3: {'c': 1}, 4: {'d': 5}, 5: {'e': 6}}

# %% [markdown]
# # Task 7
# В словарь dict7 = {'a': 1, 'b': 2, 'c': 1} добавьте новую пару ('d', 3)

# %%
dict7 = {'a': 1, 'b': 2, 'c': 1}

# %%
dict7['d']=3
dict7
# Out:
# {'a': 1, 'b': 2, 'c': 1, 'd': 3}

# %% [markdown]
# # Task 9
# Даны два словаря ```d1 = {'a': 1, 'b': 2}```, ```d2 = {'c': 3, 'd': 4}```, объедините их в переменной  dict9. Используйте `update()`

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'c': 3, 'd': 4}

# %%
dict9={}
dict9.update(d1)
dict9.update(d2)

# %%
dict9
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
